# %%
import os
os.chdir("../")

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
# Import libraries
print(os.getcwd())
import numpy as np
import glob
from infer import Inference

# %%
# load model
model = Inference()

# %%
# bulk prediction
src_dir = "[ROTATED_IMAGE_DIR]"
image_paths = glob.glob(f"{src_dir}/*")
y_pred = np.zeros(shape=(len(image_paths), ))
for i, path in enumerate(image_paths):
    y_pred[i] = model.predict(model_name="vit", image_path=path, postprocess_and_save=True, save_img_dir=os.path.join(src_dir, "predictions"))

print(y_pred)
